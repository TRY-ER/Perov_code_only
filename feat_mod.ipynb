# %%
import pandas as pd

# %%
main_df= pd.read_csv("./outputs/data/trainable_feat_mod.csv")

# %%
main_df.head()
# Out:
#    Cell_area_measured_numeric  Cell_architecture_cat  \
# 0                   -0.052185              -0.640106
# 1                   -0.052185              -0.640106
# 2                   -0.052185              -0.640106
# 3                   -0.052185              -0.640106
# 4                   -0.052185              -0.640106
#
#    Substrate_stack_sequence_0  Substrate_stack_sequence_1  \
# 0                    0.293303                   -0.318275
# 1                    0.293303                   -0.318275
# 2                    0.293303                   -0.318275
# 3                    0.293303                   -0.318275
# 4                    0.293303                   -0.318275
#
#    Substrate_stack_sequence_2  Substrate_stack_sequence_3  \
# 0                    0.340182                    0.172354
# 1                    0.340182                    0.172354
# 2                    0.340182                    0.172354
# 3                    0.340182                    0.172354
# 4                    0.340182                    0.172354
#
#    Substrate_stack_sequence_4  ETL_stack_sequence_0  ETL_stack_sequence_1  \
# 0                    0.337621              0.883848              0.706541
# 1                    0.337621              0.883848              0.706541
# 2                    0.337621              0.883848              0.706541
# 3                    0.337621              0.883848              0.706541
# 4                    0.337621              0.883848              0.706541
#
#    ETL_stack_sequence_2  ...  Backcontact_thickness_list_2  \
# 0              0.141815  ...                     -0.019487
# 1              0.141815  ...                     -0.019487
# 2              0.141815  ...                     -0.019487
# 3              0.141815  ...                     -0.019487
# 4              0.141815  ...                     -0.019487
#
#    Backcontact_thickness_list_3  Backcontact_thickness_list_4  \
# 0                     -0.014683                     -0.017949
# 1                     -0.014683                     -0.017949
# 2                     -0.014683                     -0.017949
# 3                     -0.014683                     -0.017949
# 4                     -0.014683                     -0.017949
#
#    Backcontact_deposition_procedure_0  Backcontact_deposition_procedure_1  \
# 0                           -0.231186                            0.211417
# 1                           -0.231186                            0.211417
# 2                           -0.231186                            0.211417
# 3                           -0.231186                            0.211417
# 4                           -0.231186                            0.211417
#
#    Backcontact_deposition_procedure_2  Backcontact_deposition_procedure_3  \
# 0                            0.373221                            0.126237
# 1                            0.373221                            0.126237
# 2                            0.373221                            0.126237
# 3                            0.373221                            0.126237
# 4                            0.373221                            0.126237
#
#    Backcontact_deposition_procedure_4  Encapsulation_bool  PCE_categorical
# 0                             0.29959           -0.345242                5
# 1                             0.29959           -0.345242                5
# 2                             0.29959           -0.345242                5
# 3                             0.29959           -0.345242                5
# 4                             0.29959           -0.345242                5
#
# [5 rows x 115 columns]

# %%
#modifying substrate stack sequence parameters
# main_df = main_df.drop(["Substrate_stack_sequence_2","Substrate_stack_sequence_3","Substrate_stack_sequence_4"],axis=1)

main_df = main_df.drop(["Substrate_stack_sequence_3","Substrate_stack_sequence_4",
                        "ETL_stack_sequence_4",
                        "ETL_stack_sequence_5",
                        "ETL_stack_sequence_6",
                        "ETL_deposition_procedure_4",
                        "ETL_deposition_procedure_5",
                        "ETL_deposition_procedure_5",
                        "Perovskite_composition_b_ions_2",
                        "Perovskite_composition_b_ions_3",
                        "Perovskite_composition_b_ions_coefficients_2",
                        "Perovskite_composition_b_ions_coefficients_3",
                        "Perovskite_composition_c_ions_2",
                        "Perovskite_composition_c_ions_3",
                        "Perovskite_composition_c_ions_coefficients_2",
                        "Perovskite_composition_c_ions_coefficients_3",
                        "Perovskite_deposition_procedure_3",
                        "Perovskite_deposition_procedure_4",
                        "Perovskite_deposition_procedure_5",
                        "Perovskite_deposition_aggregation_state_of_reactants_3",
                        "Perovskite_deposition_aggregation_state_of_reactants_4",
                        "Perovskite_deposition_aggregation_state_of_reactants_5",
                        "Perovskite_deposition_synthesis_atmosphere_3",
                        "Perovskite_deposition_synthesis_atmosphere_4",
                        "Perovskite_deposition_synthesis_atmosphere_5",
                        "Perovskite_deposition_solvents_4",
                        "Perovskite_deposition_solvents_5",
                        "Perovskite_deposition_solvents_mixing_ratios_4",
                        "Perovskite_deposition_solvents_mixing_ratios_5",
                        "HTL_additives_compounds_4",
                        "HTL_deposition_procedure_3",
                        "HTL_deposition_procedure_4",
                        "HTL_deposition_procedure_5",
                        "Backcontact_stack_sequence_3",
                        "Backcontact_stack_sequence_4",
                        "Backcontact_thickness_list_3",
                        "Backcontact_thickness_list_4",
                        "Backcontact_deposition_procedure_3",
                        "Backcontact_deposition_procedure_4"
                       ],axis=1)

# %%
main_df.to_csv("./outputs/data/feat_mod_scaled_data.csv",index=False)
