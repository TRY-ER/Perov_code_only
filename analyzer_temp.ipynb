# %%
import pandas as pd

# %%
use_df = pd.read_csv("./inputs/standard_ml_preprocessed_df.csv")
for key,value in zip(use_df.columns,use_df.isna().sum()):
    print(key,value)
# Out:
# PCE_categorical 0
# Cell_area_measured_numeric 0
# Cell_architecture_cat 0
# Substrate_stack_sequence_0 0
# Substrate_stack_sequence_1 0
# Substrate_stack_sequence_2 0
# Substrate_stack_sequence_3 0
# Substrate_stack_sequence_4 0
# ETL_stack_sequence_0 0
# ETL_stack_sequence_1 0
# ETL_stack_sequence_2 0
# ETL_stack_sequence_3 0
# ETL_stack_sequence_4 0
# ETL_stack_sequence_5 0
# ETL_stack_sequence_6 0
# ETL_deposition_procedure_0 0
# ETL_deposition_procedure_1 0
# ETL_deposition_procedure_2 0
# ETL_deposition_procedure_3 0
# ETL_deposition_procedure_4 0
# ETL_deposition_procedure_5 0
# ETL_deposition_procedure_6 0
# Perovskite_composition_a_ions_0 0
# Perovskite_composition_a_ions_1 0
# Perovskite_composition_a_ions_2 0
# Perovskite_composition_a_ions_3 0
# Perovskite_composition_a_ions_coefficients_0 0
# Perovskite_composition_a_ions_coefficients_1 0
# Perovskite_composition_a_ions_coefficients_2 0
# Perovskite_composition_a_ions_coefficients_3 0
# Perovskite_composition_b_ions_0 0
# ...
